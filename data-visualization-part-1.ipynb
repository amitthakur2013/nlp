# %% [markdown]
# <a href="https://colab.research.google.com/github/amitthakur2013/nlp/blob/master/data-visualization-part-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !pip install xlrd

# %%
path="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx"
df_can=pd.read_excel(path,skiprows=range(20),skip_footer=2,sheet_name="Canada by Citizenship")
print('Data read Successfully!')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py:188: FutureWarning: the 'skip_footer' keyword is deprecated, use 'skipfooter' instead
#   return func(*args, **kwargs)
# Data read Successfully!

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0  Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1  Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2  Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3  Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4  Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
#
# [5 rows x 43 columns]

# %%
df_can.drop(['DevName'],axis=1,inplace=True)
df_can.head(2)

# %%
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'},inplace=True)
df_can.columns.values
# Out:
# array(['Country', 'Continent', 'Region', 1980, 1981, 1982, 1983, 1984,
#        1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013], dtype=object)

# %%
df_can.dtypes

# %%
df_can.shape
# Out:
# (195, 37)

# %%
df_can.head(2)
# Out:
#        Country Continent           Region  1980  ...  2010  2011  2012  2013
# 0  Afghanistan      Asia    Southern Asia    16  ...  1758  2203  2635  2004
# 1      Albania    Europe  Southern Europe     1  ...   561   539   620   603
#
# [2 rows x 37 columns]

# %%
df_can.set_index('Country',inplace=True)

# %%
df_can.head(2)
# Out:
#             Continent           Region  1980  1981  ...  2010  2011  2012  2013
# Country                                             ...
# Afghanistan      Asia    Southern Asia    16    39  ...  1758  2203  2635  2004
# Albania        Europe  Southern Europe     1     0  ...   561   539   620   603
#
# [2 rows x 36 columns]

# %%
df_can['Total']=df_can.sum(axis=1)

# %%
df_can.head(2)
# Out:
#             Continent           Region  1980  1981  ...  2011  2012  2013  Total
# Country                                             ...
# Afghanistan      Asia    Southern Asia    16    39  ...  2203  2635  2004  58639
# Albania        Europe  Southern Europe     1     0  ...   539   620   603  15699
#
# [2 rows x 37 columns]

# %%
years=list(map(int, range(1980,2014)))
#years
df=pd.DataFrame(df_can[years])
df['Total'] = df_can['Total']
df.head()
# Out:
#                 1980  1981  1982  1983  1984  ...  2010  2011  2012  2013  Total
# Country                                       ...
# Afghanistan       16    39    39    47    71  ...  1758  2203  2635  2004  58639
# Albania            1     0     0     0     0  ...   561   539   620   603  15699
# Algeria           80    67    71    69    63  ...  4752  4325  3774  4331  69439
# American Samoa     0     1     0     0     0  ...     0     0     0     0      6
# Andorra            0     0     0     0     0  ...     0     0     1     1     15
#
# [5 rows x 35 columns]

# %%
# %matplotlib inline
import matplotlib as mlp
import matplotlib.pyplot as plt

# %%
mlp.style.use(['ggplot'])

# %% [markdown]
# **Line Plot**

# %%
years=list(map(int, range(1980,2014)))
haiti=pd.DataFrame(df_can.loc['Haiti'],years)
haiti.head()
# Out:
#      Haiti
# 1980  1666
# 1981  3692
# 1982  3498
# 1983  2860
# 1984  1418

# %%
haiti.plot(kind="line",figsize=(10,6))
plt.title("Haiti EarthQuake Impact")
plt.xlabel("Years")
plt.ylabel("No of Migrants")
plt.text(2000,6000,"Earthquake-2010")
plt.show()

# %%
df=df_can.loc[['India','China'],years].transpose()
df.index.name=None
df.head()
# Out:
# Country  India  China
# 1980      8880   5123
# 1981      8670   6682
# 1982      8147   3308
# 1983      7338   1863
# 1984      5704   1527

# %%
df.plot(kind="line",figsize=(10,6))
plt.title('India and China')
plt.xlabel('Years')
plt.ylabel('No of Migrants')
plt.show()

# %%
df_can.sort_values(by='Total', ascending=False , inplace=True)
df_can.head()
# Out:
#                                                    Continent  ...   Total
# Country                                                       ...
# India                                                   Asia  ...  691904
# China                                                   Asia  ...  659962
# United Kingdom of Great Britain and Northern Ir...    Europe  ...  551500
# Philippines                                             Asia  ...  511391
# Pakistan                                                Asia  ...  241600
#
# [5 rows x 37 columns]

# %%
df=df_can.head()

# %%
df=df[years].transpose()

df
# Out:
# Country  India  China  ...  Philippines  Pakistan
# 1980      8880   5123  ...         6051       978
# 1981      8670   6682  ...         5921       972
# 1982      8147   3308  ...         5249      1201
# 1983      7338   1863  ...         4562       900
# 1984      5704   1527  ...         3801       668
# 1985      4211   1816  ...         3150       514
# 1986      7150   1960  ...         4166       691
# 1987     10189   2643  ...         7360      1072
# 1988     11522   2758  ...         8639      1334
# 1989     10343   4323  ...        11865      2261
# 1990     12041   8076  ...        12509      2470
# 1991     13734  14255  ...        12718      3079
# 1992     13673  10846  ...        13670      4071
# 1993     21496   9817  ...        20479      4777
# 1994     18620  13128  ...        19532      4666
# 1995     18489  14398  ...        15864      4994
# 1996     23859  19415  ...        13692      9125
# 1997     22268  20475  ...        11549     13073
# ...

# %%
df.plot(kind="line",figsize=(10,8))
plt.title("Plots Of Various Countries")
plt.xlabel("Years")
plt.ylabel("No of Migrants")
plt.show()

# %%
df.plot(kind="area",figsize=(10,8),stacked=False,alpha=0.45)
plt.title("Area Plot")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **Bar Graph Analysis**

# %%
df_iceland=df_can.loc['Iceland',years]

# %%
df_iceland.plot(kind='bar',figsize=(10,6),rot=90)
plt.title("Bar-Graph")
plt.xlabel("Years")
plt.ylabel("No of Migrants")
for value in df_iceland.index.values:
  plt.annotate(df_iceland[value], # text to display
             xy=(int(value)-1980, int(df_iceland[value])+1), 
             color="darkblue",                    # start the text at at point (year 2008 , pop 30)
             rotation=0,                  # based on trial and error to match the arrow
             va='bottom',                    # want the text to be vertically 'bottom' aligned
              )
plt.show()

# %%
df_top15=df_can['Total'].head(15)

# %%
df_top15.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Number of Immigrants')
plt.title('Top 15 Conuntries Contributing to the Immigration to Canada between 1980 - 2013')
for index, value in enumerate(df_top15): 
    label = format(int(value), ',') # format int with commas
    
    # place text at the end of bar (subtracting 47000 from x, and 0.1 from y to make it fit within the bar)
    plt.annotate(label, xy=(value - 47000, index - 0.10), color='white')
plt.show()

# %% [markdown]
# **Histogram**
